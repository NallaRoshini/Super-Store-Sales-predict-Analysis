# %%
# Extractig Data

import pandas as pd
import numpy as np

excel_file ='C:\\Users\\nalla_enejoi3\\OneDrive\Desktop\\fda project\\SuperStore.xlsx' 
df = pd.read_excel(excel_file)

#printing dimension of dataframe,i.e,number of rows and columns
print(df.shape)
no_of_rows,no_of_cols=df.shape
print(f'Number of rows: {no_of_rows}')
print(f'Number of columns: {no_of_cols}')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\nalla_enejoi3\AppData\Local\Temp\ipykernel_12836\1725990778.py:6: SyntaxWarning: invalid escape sequence '\D'
#   excel_file ='C:\\Users\\nalla_enejoi3\\OneDrive\Desktop\\fda project\\SuperStore.xlsx'
# (5901, 20)
# Number of rows: 5901
# Number of columns: 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   datetime64[ns]
#  3   Ship Date         5901 non-null   datetime64[ns]
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6                     Order Date  \
# count       5901.000000                           5901
# mean        5022.422471  2020-02-29 01:53:57.620742144
# min            1.000000            2019-01-01 00:00:00
# 25%         2486.000000            2019-09-11 00:00:00
# 50%         5091.000000            2020-03-16 00:00:00
# 75%         7456.000000            2020-09-14 00:00:00
# max         9994.000000            2020-12-31 00:00:00
# std         2877.977184                            NaN
#
#                            Ship Date        Sales       Profit
# count                           5901  5877.000000  5901.000000
# mean   2020-03-04 00:08:47.097102336   265.097916    29.700408
# min              2019-01-05 00:00:00     0.836000 -6599.978000
# 25%              2019-09-15 00:00:00    71.976000     1.795500
# 50%              2020-03-19 00:00:00   128.648000     8.502500
# 75%              2020-09-16 00:00:00   265.170000    28.615000
# ...

# %%
import matplotlib.pyplot as plt
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
print(df)
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1                 4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2                 4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3                 2898  US-2019-164630 2019-01-04 2019-01-09  Standard Class
# 4                 5868  CA-2019-158211 2019-01-04 2019-01-08  Standard Class
# ...                ...             ...        ...        ...             ...
# 5896              8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# 5897              8605  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# 5898              8606  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# 5899              9494  CA-2019-105207 2019-01-03 2019-01-08  Standard Class
# 5900              9495  CA-2019-105207 2019-01-03 2019-01-08  Standard Class
#
# ...

# %%
# To print 1st few rows of dataframe
print(df.head())
# To print last few rows of dataframe
print(df.tail())
# Out:
#    Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1              4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2              4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3              2898  US-2019-164630 2019-01-04 2019-01-09  Standard Class
# 4              5868  CA-2019-158211 2019-01-04 2019-01-08  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg
# 2    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg
# 3    EB-13975     Erica Bern  Corporate  United States     Charlotte
# 4    BP-11185   Ben Peterman  Corporate  United States  Philadelphia
#
#             State Region       Product ID         Category Sub-Category  \
# ...
